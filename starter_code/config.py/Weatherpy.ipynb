# %%
# %matplotlib inline

# %%
## WeatherPy
## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
x = [1,2,3]
x[0] = 5
x
# Out:
# [5, 2, 3]

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 632

# %%
## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url= f"{url}appid={weather_api_key}&units={cities}&q="

    city_url = url + "&q=" + city.replace(" ","+")
    
    
    #Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mananjary
# Processing Record 2 of Set 1 | urengoy
# Processing Record 3 of Set 1 | mangrol
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | yakeshi
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | tuatapere
# Processing Record 9 of Set 1 | te anau
# Processing Record 10 of Set 1 | murgab
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | sioux lookout
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | tecoanapa
# Processing Record 15 of Set 1 | abu samrah
# Processing Record 16 of Set 1 | razdolnoye
# Processing Record 17 of Set 1 | camacha
# Processing Record 18 of Set 1 | soure
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | rio grande
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | mao
# Processing Record 26 of Set 1 | matara
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | bud
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | palu
# Processing Record 34 of Set 1 | ouesso
# Processing Record 35 of Set 1 | codrington
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | myaundzha
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | itaugua
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | asau
# Processing Record 46 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | alice springs
# Processing Record 50 of Set 1 | horsham
# Processing Record 0 of Set 2 | leer
# Processing Record 1 of Set 2 | beringovskiy
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | bonthe
# Processing Record 4 of Set 2 | bu salim
# City not found. Skipping...
# Processing Record 5 of Set 2 | marawi
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | sao felix do xingu
# Processing Record 8 of Set 2 | sinnamary
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | muros
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | bela
# Processing Record 14 of Set 2 | peterhead
# Processing Record 15 of Set 2 | mount isa
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | ha giang
# Processing Record 18 of Set 2 | saint-francois
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | filadelfia
# Processing Record 21 of Set 2 | roma
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | korla
# Processing Record 28 of Set 2 | batagay-alyta
# Processing Record 29 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 2 | ponnani
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | saravan
# Processing Record 33 of Set 2 | rikitea
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | biak
# Processing Record 36 of Set 2 | palmer
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | cururupu
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | kyra
# Processing Record 43 of Set 2 | college
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | dawlatabad
# Processing Record 46 of Set 2 | srednekolymsk
# Processing Record 47 of Set 2 | fenoarivo
# Processing Record 48 of Set 2 | marienburg
# Processing Record 49 of Set 2 | bojnurd
# Processing Record 0 of Set 3 | katsuura
# Processing Record 1 of Set 3 | sibay
# Processing Record 2 of Set 3 | kemijarvi
# Processing Record 3 of Set 3 | hualmay
# Processing Record 4 of Set 3 | xuzhou
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | ponta delgada
# Processing Record 7 of Set 3 | vallenar
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | belyy yar
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | kerema
# Processing Record 15 of Set 3 | san cristobal
# Processing Record 16 of Set 3 | carballo
# Processing Record 17 of Set 3 | tomatlan
# Processing Record 18 of Set 3 | oum hadjer
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | dubovskoye
# Processing Record 21 of Set 3 | klaksvik
# Processing Record 22 of Set 3 | pacific grove
# Processing Record 23 of Set 3 | bubaque
# Processing Record 24 of Set 3 | sri aman
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | wodonga
# Processing Record 27 of Set 3 | bambanglipuro
# Processing Record 28 of Set 3 | bilibino
# Processing Record 29 of Set 3 | kermanshah
# Processing Record 30 of Set 3 | talnakh
# Processing Record 31 of Set 3 | vanavara
# Processing Record 32 of Set 3 | buriti alegre
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | brae
# Processing Record 35 of Set 3 | eureka
# Processing Record 36 of Set 3 | mandalgovi
# Processing Record 37 of Set 3 | sambava
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | talara
# Processing Record 40 of Set 3 | santa ana
# Processing Record 41 of Set 3 | plouzane
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | akdepe
# Processing Record 44 of Set 3 | cape coast
# Processing Record 45 of Set 3 | virginia beach
# Processing Record 46 of Set 3 | luchegorsk
# Processing Record 47 of Set 3 | katangli
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 0 of Set 4 | hithadhoo
# Processing Record 1 of Set 4 | zychlin
# Processing Record 2 of Set 4 | los llanos de aridane
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | norilsk
# Processing Record 6 of Set 4 | yellowknife
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | yantarnyy
# Processing Record 9 of Set 4 | sola
# Processing Record 10 of Set 4 | birnin kebbi
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | shelburne
# Processing Record 14 of Set 4 | alofi
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | qandala
# Processing Record 17 of Set 4 | mirina
# City not found. Skipping...
# Processing Record 18 of Set 4 | angoram
# Processing Record 19 of Set 4 | zyryanovsk
# Processing Record 20 of Set 4 | sao gabriel da cachoeira
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | saint-philippe
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | marsa matruh
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | bluff
# Processing Record 29 of Set 4 | oussouye
# Processing Record 30 of Set 4 | luderitz
# Processing Record 31 of Set 4 | douglas
# Processing Record 32 of Set 4 | torbay
# Processing Record 33 of Set 4 | liusha
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 4 | samarai
# Processing Record 37 of Set 4 | playa del carmen
# Processing Record 38 of Set 4 | henties bay
# Processing Record 39 of Set 4 | ajaccio
# Processing Record 40 of Set 4 | tucurui
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | jiujiang
# Processing Record 43 of Set 4 | jatai
# Processing Record 44 of Set 4 | salalah
# Processing Record 45 of Set 4 | santa cruz de la palma
# Processing Record 46 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 4 | leningradskiy
# Processing Record 48 of Set 4 | garden city
# Processing Record 49 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 0 of Set 5 | jizan
# Processing Record 1 of Set 5 | nemuro
# Processing Record 2 of Set 5 | cayenne
# Processing Record 3 of Set 5 | terrace
# Processing Record 4 of Set 5 | cabedelo
# Processing Record 5 of Set 5 | san policarpo
# Processing Record 6 of Set 5 | hermanus
# Processing Record 7 of Set 5 | buta
# Processing Record 8 of Set 5 | adre
# Processing Record 9 of Set 5 | seoul
# Processing Record 10 of Set 5 | manicore
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | provost
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | sao filipe
# Processing Record 15 of Set 5 | goderich
# Processing Record 16 of Set 5 | pangnirtung
# Processing Record 17 of Set 5 | kahului
# Processing Record 18 of Set 5 | hirara
# Processing Record 19 of Set 5 | buncrana
# Processing Record 20 of Set 5 | sept-iles
# Processing Record 21 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 5 | aberdeen
# Processing Record 23 of Set 5 | natal
# Processing Record 24 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 5 | waingapu
# Processing Record 26 of Set 5 | nuevo san carlos
# Processing Record 27 of Set 5 | darhan
# Processing Record 28 of Set 5 | berlevag
# Processing Record 29 of Set 5 | buala
# Processing Record 30 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 5 | coreau
# Processing Record 32 of Set 5 | dzerzhinsk
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | marsala
# Processing Record 35 of Set 5 | namatanai
# Processing Record 36 of Set 5 | goedereede
# Processing Record 37 of Set 5 | caluquembe
# Processing Record 38 of Set 5 | bendigo
# Processing Record 39 of Set 5 | staryy nadym
# Processing Record 40 of Set 5 | guerrero negro
# Processing Record 41 of Set 5 | hinton
# Processing Record 42 of Set 5 | tomari
# Processing Record 43 of Set 5 | bereda
# Processing Record 44 of Set 5 | port-gentil
# Processing Record 45 of Set 5 | ahipara
# Processing Record 46 of Set 5 | sorong
# Processing Record 47 of Set 5 | kruisfontein
# Processing Record 48 of Set 5 | rawson
# Processing Record 49 of Set 5 | geraldton
# Processing Record 0 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 6 | huancabamba
# Processing Record 2 of Set 6 | buraydah
# Processing Record 3 of Set 6 | two rivers
# Processing Record 4 of Set 6 | cukai
# Processing Record 5 of Set 6 | nanakuli
# Processing Record 6 of Set 6 | rocha
# Processing Record 7 of Set 6 | bay roberts
# Processing Record 8 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | lakatoro
# Processing Record 11 of Set 6 | kokopo
# Processing Record 12 of Set 6 | jalingo
# Processing Record 13 of Set 6 | ipora
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | yar-sale
# Processing Record 17 of Set 6 | songjianghe
# Processing Record 18 of Set 6 | ichinohe
# Processing Record 19 of Set 6 | saintes
# Processing Record 20 of Set 6 | san gabriel
# Processing Record 21 of Set 6 | starokozache
# Processing Record 22 of Set 6 | shakhtinsk
# Processing Record 23 of Set 6 | bathsheba
# Processing Record 24 of Set 6 | binghamton
# Processing Record 25 of Set 6 | longyearbyen
# Processing Record 26 of Set 6 | casas grandes
# Processing Record 27 of Set 6 | roald
# Processing Record 28 of Set 6 | hamilton
# Processing Record 29 of Set 6 | isangel
# Processing Record 30 of Set 6 | khatanga
# Processing Record 31 of Set 6 | fairbanks
# Processing Record 32 of Set 6 | castro
# Processing Record 33 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 6 | mehamn
# Processing Record 35 of Set 6 | kongwa
# Processing Record 36 of Set 6 | adrar
# Processing Record 37 of Set 6 | shingu
# Processing Record 38 of Set 6 | choix
# Processing Record 39 of Set 6 | vardo
# Processing Record 40 of Set 6 | saint-augustin
# Processing Record 41 of Set 6 | evensk
# Processing Record 42 of Set 6 | ritchie
# Processing Record 43 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | esso
# Processing Record 45 of Set 6 | olinda
# Processing Record 46 of Set 6 | bundaberg
# Processing Record 47 of Set 6 | saint anthony
# Processing Record 48 of Set 6 | porto tolle
# Processing Record 49 of Set 6 | baiyin
# Processing Record 0 of Set 7 | arenapolis
# Processing Record 1 of Set 7 | arlit
# Processing Record 2 of Set 7 | fallon
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | wilmington
# Processing Record 5 of Set 7 | de aar
# Processing Record 6 of Set 7 | tautira
# Processing Record 7 of Set 7 | padang
# Processing Record 8 of Set 7 | grenville
# Processing Record 9 of Set 7 | fershampenuaz
# Processing Record 10 of Set 7 | solton
# Processing Record 11 of Set 7 | mbandaka
# Processing Record 12 of Set 7 | itarema
# Processing Record 13 of Set 7 | kaitangata
# Processing Record 14 of Set 7 | zhanaozen
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | culebra
# Processing Record 17 of Set 7 | general pico
# Processing Record 18 of Set 7 | oriximina
# Processing Record 19 of Set 7 | nalut
# Processing Record 20 of Set 7 | el fuerte
# Processing Record 21 of Set 7 | jijiga
# Processing Record 22 of Set 7 | kargopol
# Processing Record 23 of Set 7 | turukhansk
# Processing Record 24 of Set 7 | astana
# Processing Record 25 of Set 7 | butaritari
# Processing Record 26 of Set 7 | dauriya
# Processing Record 27 of Set 7 | dire
# Processing Record 28 of Set 7 | mandan
# Processing Record 29 of Set 7 | kaspiysk
# Processing Record 30 of Set 7 | charters towers
# Processing Record 31 of Set 7 | lielvarde
# Processing Record 32 of Set 7 | teguise
# Processing Record 33 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | sitka
# Processing Record 36 of Set 7 | atasu
# Processing Record 37 of Set 7 | fray bentos
# Processing Record 38 of Set 7 | port-cartier
# Processing Record 39 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 7 | faya
# Processing Record 41 of Set 7 | khryashchevka
# Processing Record 42 of Set 7 | quatre cocos
# Processing Record 43 of Set 7 | beberibe
# Processing Record 44 of Set 7 | neiafu
# Processing Record 45 of Set 7 | san isidro
# Processing Record 46 of Set 7 | nuuk
# Processing Record 47 of Set 7 | tuy hoa
# Processing Record 48 of Set 7 | amarante do maranhao
# Processing Record 49 of Set 7 | ploemeur
# Processing Record 0 of Set 8 | bandiagara
# Processing Record 1 of Set 8 | kodiak
# Processing Record 2 of Set 8 | kavaratti
# Processing Record 3 of Set 8 | pacocha
# Processing Record 4 of Set 8 | medvezhyegorsk
# Processing Record 5 of Set 8 | gornopravdinsk
# Processing Record 6 of Set 8 | koumra
# Processing Record 7 of Set 8 | mago
# Processing Record 8 of Set 8 | denpasar
# Processing Record 9 of Set 8 | gat
# Processing Record 10 of Set 8 | faanui
# Processing Record 11 of Set 8 | tongren
# Processing Record 12 of Set 8 | haines junction
# Processing Record 13 of Set 8 | tiarei
# Processing Record 14 of Set 8 | show low
# Processing Record 15 of Set 8 | sanguem
# Processing Record 16 of Set 8 | kilindoni
# Processing Record 17 of Set 8 | dunedin
# Processing Record 18 of Set 8 | salisbury
# Processing Record 19 of Set 8 | hachinohe
# Processing Record 20 of Set 8 | tilichiki
# Processing Record 21 of Set 8 | nchelenge
# Processing Record 22 of Set 8 | fort frances
# Processing Record 23 of Set 8 | cidreira
# Processing Record 24 of Set 8 | olafsvik
# Processing Record 25 of Set 8 | tessalit
# Processing Record 26 of Set 8 | zhezkazgan
# Processing Record 27 of Set 8 | saint-joseph
# Processing Record 28 of Set 8 | ronneby
# Processing Record 29 of Set 8 | melioratorov
# Processing Record 30 of Set 8 | cape canaveral
# Processing Record 31 of Set 8 | balabac
# Processing Record 32 of Set 8 | guarapari
# Processing Record 33 of Set 8 | chebsara
# Processing Record 34 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 8 | belfast
# Processing Record 36 of Set 8 | codajas
# Processing Record 37 of Set 8 | basco
# Processing Record 38 of Set 8 | airai
# Processing Record 39 of Set 8 | lasa
# Processing Record 40 of Set 8 | zhigansk
# Processing Record 41 of Set 8 | vila franca do campo
# Processing Record 42 of Set 8 | karasburg
# Processing Record 43 of Set 8 | valley city
# Processing Record 44 of Set 8 | soldatskiy
# City not found. Skipping...
# Processing Record 45 of Set 8 | namwala
# Processing Record 46 of Set 8 | kasongo-lunda
# Processing Record 47 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 48 of Set 8 | kurchum
# Processing Record 49 of Set 8 | elat
# Processing Record 0 of Set 9 | izberbash
# Processing Record 1 of Set 9 | emilio carranza
# Processing Record 2 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 9 | palm springs
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | vilcun
# Processing Record 6 of Set 9 | creel
# Processing Record 7 of Set 9 | kati
# Processing Record 8 of Set 9 | smoky lake
# Processing Record 9 of Set 9 | nouakchott
# Processing Record 10 of Set 9 | chodov
# Processing Record 11 of Set 9 | xingyi
# Processing Record 12 of Set 9 | bella vista

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %%
### Create the Scatter Plots Requested

#### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], alpha=0.75, edgecolors="black",facecolors="red")


# Incorporate the other graph properties
# YOUR CODE HERE

(plt.title('Latitude vs Temperature'), plt.xlabel("Latitude"), plt.ylabel("Temperature"))

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
#### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. Humidity
# YOUR CODE HERE

plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], alpha=0.75, edgecolors="black",facecolors="green")


# Incorporate the other graph properties
# YOUR CODE HERE

(plt.title('Latitude vs Humidity'), plt.xlabel("Latitude"), plt.ylabel("Humidity"))

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
#### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], alpha=0.75, edgecolors="black",facecolors="gray")


# Incorporate the other graph properties
# YOUR CODE HERE

(plt.title('Latitude vs Cloudiness'), plt.xlabel("Latitude"), plt.ylabel("Cloudiness"))

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
#### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], alpha=0.75, edgecolors="black",facecolors="blue")



# Incorporate the other graph properties
# YOUR CODE HERE

(plt.title('Latitude vs Wind Speed'), plt.xlabel("Latitude"), plt.ylabel("Wind Speed"))

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Per y = mx + b, m == slope, b == intercept, r == r-value
# p == p-value, stderr = standard error

def linear_regression(x,y,x_label,y_label):
    (m, b, r, p, stderr) = linregress(x,y)
    reg_val = (m * x) + b
    reg_equ = f"y={(round(m,4))}x + {(round(b,4))}"

    plt.figure(figsize=(15,10))
    plt.scatter(x,y,color='lightblue',edgecolor='steelblue')
    plt.plot(x,reg_val,color='red')
    plt.annotate(reg_equ,(10,10),color='red',fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.xlabel(x_label,fontsize=14)
    plt.ylabel(y_label,fontsize=14)
    print(f"The r-squared value is: {r**2}.")
    plt.show()
# x_values = san_diego_housing['AveRooms']
# y_values = san_diego_housing['MEDV']
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(x_values,y_values)
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
# plt.xlabel('Rooms in House')
# plt.ylabel('Median House Prices ($100,000)')
# plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

north_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
north_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

south_hemi_df = city_data_df[city_data_df['Lat'] <0]

# Display sample data
south_hemi_df.head()

# %%
###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Max Temp']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Max Temp']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# %%
### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Humidity']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
# Southern Hemisphere
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Humidity']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Cloudiness']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
# Southern Hemisphere
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Cloudiness']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Wind Speed']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
# Southern Hemisphere
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Wind Speed']
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
